# %% [markdown]
# # Verificacion del entorno
#
# Comprueba que el kernel `Python (labs-deep-learning)` y las dependencias principales esten disponibles.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import sklearn
import torch

print("Python    :", sys.version.split()[0])
print("numpy     :", np.__version__)
print("pandas    :", pd.__version__)
print("matplotlib:", matplotlib.__version__)
print("sklearn   :", sklearn.__version__)
print("torch     :", torch.__version__)
print("CUDA disp :", torch.cuda.is_available())
# Out:
# Python    : 3.13.0
# numpy     : 2.4.6
# pandas    : 2.3.3
# matplotlib: 3.11.0
# sklearn   : 1.9.0
# torch     : 2.12.1+cpu
# CUDA disp : False

# %%
# Prueba rapida de un tensor en PyTorch
x = torch.randn(3, 3)
print(x)
print("Suma:", x.sum().item())
